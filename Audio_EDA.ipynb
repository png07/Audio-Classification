# %%
#####dataset url https://urbansounddataset.weebly.com/urbansound8k.html

# %%
import matplotlib.pyplot as plt

# %%
filename=r'C:\Users\pratik\Documents\Projects\audio_classification\UrbanSound8K\audio\fold1\193394-3-0-10.wav'

# %%
import IPython.display as ipd
import librosa
import librosa.display

# %%
### Dog Sound
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
### Sound
filename=r'C:\Users\pratik\Documents\Projects\audio_classification\UrbanSound8K\audio\fold1\7061-6-0-0.wav'
plt.figure(figsize=(14,5))
data,sample_rate=librosa.load(filename)
librosa.display.waveshow(data,sr=sample_rate)
ipd.Audio(filename)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
sample_rate
# Out:
# 22050

# %%
from scipy.io import wavfile as wav
wave_sample_rate, wave_audio=wav.read(filename)

# %%
wave_sample_rate
# Out:
# 44100

# %%
wave_audio
# Out:
# array([[0, 0],
#        [0, 0],
#        [0, 0],
#        ...,
#        [1, 0],
#        [1, 1],
#        [0, 0]], dtype=int16)

# %%
data
# Out:
# array([-7.4505806e-09,  2.9802322e-08,  4.8428774e-08, ...,
#         1.0127544e-05,  2.3271263e-05,  7.0009992e-06], dtype=float32)

# %%
import pandas as pd

metadata=pd.read_csv(r'C:\Users\pratik\Documents\Projects\audio_classification\UrbanSound8K\metadata\metadata2.csv')
metadata.head(10)
# Out:
#    Unnamed: 0     slice_file_name      fsID      start        end  salience  \
# 0           0    100032-3-0-0.wav  100032.0   0.000000   0.317551       1.0
# 1           1  100263-2-0-117.wav  100263.0  58.500000  62.500000       1.0
# 2           2  100263-2-0-121.wav  100263.0  60.500000  64.500000       1.0
# 3           3  100263-2-0-126.wav  100263.0  63.000000  67.000000       1.0
# 4           4  100263-2-0-137.wav  100263.0  68.500000  72.500000       1.0
# 5           5  100263-2-0-143.wav  100263.0  71.500000  75.500000       1.0
# 6           6  100263-2-0-161.wav  100263.0  80.500000  84.500000       1.0
# 7           7    100263-2-0-3.wav  100263.0   1.500000   5.500000       1.0
# 8           8   100263-2-0-36.wav  100263.0  18.000000  22.000000       1.0
# 9           9    100648-1-0-0.wav  100648.0   4.823402   5.471927       2.0
#
#    fold  classID             class
# 0     5      3.0          dog_bark
# 1     5      2.0  children_playing
# 2     5      2.0  children_playing
# 3     5      2.0  children_playing
# 4     5      2.0  children_playing
# 5     5      2.0  children_playing
# 6     5      2.0  children_playing
# 7     5      2.0  children_playing
# 8     5      2.0  children_playing
# 9    10      1.0          car_horn

# %%
metadata['class'].value_counts()
# Out:
# class
# dog_bark            1000
# children_playing    1000
# air_conditioner     1000
# street_music        1000
# engine_idling       1000
# jackhammer          1000
# drilling            1000
# siren                929
# laughter             897
# car_horn             429
# gun_shot             374
# Name: count, dtype: int64

# %%
import seaborn as sns
plt.figure(figsize=(17, 6))
counts = metadata["class"].value_counts()
sns.barplot(x=counts.index, y=counts.values)
plt.xticks(rotation=90);

# %%
plt.figure(figsize=(17, 8))
plt.pie(counts, labels=counts.index, autopct="%.2f%%")
plt.title("Distribution of Classes", fontweight="black", size=14, pad=15)
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=metadata, x='fold')
plt.title('Fold Distribution')
plt.xlabel('Fold Number')
plt.ylabel('Number of Samples')
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(data=metadata, x='salience')
plt.title('Salience Distribution')
plt.xlabel('Salience (1=Foreground, 2=Background)')
plt.ylabel('Number of Samples')
plt.show()
